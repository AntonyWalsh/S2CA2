# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Processing on the Monthly GoT data to remove false positives
# ### Output is a processed csv will import this to MongoDB

# %%
#Read in month of gameofthrones data
GoT_df = pd.read_csv('C:\\data files\\April2016 GOT.csv')

# %%
#Read in month of gameofthrones data
may = pd.read_csv('C:\\data files\\May2016 GOT.csv')

# %%
#Read in month of gameofthrones data
june = pd.read_csv('C:\\data files\\June2016 GOT.csv')

# %%
GoT_df.head()
# Out:
#             poster     recipient relationship                      tweet date  \
# 0  petuhovaksenija  yourcoollook     mentions  fri apr 01 06:34:12 +0000 2016
# 1         nassie_k      nassie_k        tweet  fri apr 01 06:34:27 +0000 2016
# 2   xgameofthrones       variety     mentions  fri apr 01 06:38:11 +0000 2016
# 3     halfmylifede    ninadobrev        reply  fri apr 01 06:46:35 +0000 2016
# 4     halfmylifede  jessicaszohr     mentions  fri apr 01 06:46:35 +0000 2016
#
#              tweet id                                              tweet  \
# 0  715789342644510720                rt @yourcoollook: Я ДИКО ХОЧУ СПАТЬ
# 1  715789405554868224  налили в клей пва сметану и ходят жрут\nтп дно...
# 2  715790345070649345  ‘game of thrones’ star iain glen joins rachel ...
# 3  715792458983084032  @ninadobrev @jessicaszohr awhhh nina and vin s...
# 4  715792458983084032  @ninadobrev @jessicaszohr awhhh nina and vin s...
#
#         hashtags  retweet status
# ...

# %%
may.head()
# Out:
#             poster     recipient relationship                      tweet date  \
# 0          hyukgae     minminnay     mentions  sun may 01 06:34:43 +0000 2016
# 1         n_vsegda      n_vsegda        tweet  sun may 01 06:46:08 +0000 2016
# 2         t_leture      lordsnow     mentions  sun may 01 06:50:34 +0000 2016
# 3  geeksmashtweets  romaniangirl     mentions  sun may 01 06:51:05 +0000 2016
# 4     thronenews99    digi_gifts     mentions  sun may 01 06:59:19 +0000 2016
#
#              tweet id                                              tweet  \
# 0  726661108610682880  rt @minminnay: spring in me ม้ามืดมาก จู่ๆขึ้น...
# 1  726663981700644864                   Миленько https://t.co/8dbfjm2biy
# 2  726665097398128641  rt @lordsnow: #gameofthrones meets the simpson...
# 3  726665227429879808  rt @romaniangirl: been watching jack taylor on...
# 4  726667299399168000  simonknuckey: rt @digi_gifts rt to #win a pers...
#
#                    hashtags  retweet status
# ...

# %%
may.tail()
# Out:
#                poster       recipient relationship  \
# 51917          g1sand       beakiddo1     mentions
# 51918          g1sand          g1sand     mentions
# 51919          g1sand    dannakilling     mentions
# 51920    katelynnec20   fallontonight     mentions
# 51921  enginyerinnova  enginyerinnova        tweet
#
#                            tweet date            tweet id  \
# 51917  wed jun 01 05:52:21 +0000 2016  737884470540414976
# 51918  wed jun 01 05:52:21 +0000 2016  737884470540414976
# 51919  wed jun 01 05:52:21 +0000 2016  737884470540414976
# 51920  wed jun 01 05:53:05 +0000 2016  737884655077195777
# 51921  wed jun 01 05:53:40 +0000 2016  737884801898778625
#
#                                                    tweet  \
# 51917  rt @beakiddo1: @vicinigrazia @nemracxad @beaki...
# 51918  rt @beakiddo1: @vicinigrazia @nemracxad @beaki...
# 51919  rt @beakiddo1: @vicinigrazia @nemracxad @beaki...
# 51920  rt @fallontonight: kit harington was pretty te...
# ...

# %%
june.head()
# Out:
#           poster        recipient relationship  \
# 0          M04th           Cutevl        reply
# 1     aRnecutska  chris_voloshina     mentions
# 2     aRnecutska       aRnecutska     mentions
# 3   Macready1306     Macready1306        tweet
# 4  wahanapenulis    wahanapenulis        tweet
#
#                        tweet date            tweet id  \
# 0  Wed Jun 01 06:32:54 +0000 2016  737894675277852674
# 1  Wed Jun 01 06:34:15 +0000 2016  737895014991302656
# 2  Wed Jun 01 06:34:15 +0000 2016  737895014991302656
# 3  Wed Jun 01 06:35:56 +0000 2016  737895438624423937
# 4  Wed Jun 01 06:38:50 +0000 2016  737896168445870080
#
#                                                tweet           hashtags  \
# 0  @Cutevl انا اصداري اقدم شيء وعادي اخذ سيلفي ما...                 []
# 1  RT @chris_voloshina: @aRnecutska моё мнение: к...                 []
# 2  RT @chris_voloshina: @aRnecutska моё мнение: к...                 []
# ...

# %%
GoT_df = GoT_df.append(may,ignore_index=True)
# Out:
# C:\Users\tonyw\AppData\Local\Temp\ipykernel_19680\745650992.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GoT_df = GoT_df.append(may,ignore_index=True)

# %%
GoT_df = GoT_df.append(june,ignore_index=True)
# Out:
# C:\Users\tonyw\AppData\Local\Temp\ipykernel_19680\1553369682.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GoT_df = GoT_df.append(june,ignore_index=True)

# %%
GoT_df.head()
# Out:
#             poster     recipient relationship                      tweet date  \
# 0  petuhovaksenija  yourcoollook     mentions  fri apr 01 06:34:12 +0000 2016
# 1         nassie_k      nassie_k        tweet  fri apr 01 06:34:27 +0000 2016
# 2   xgameofthrones       variety     mentions  fri apr 01 06:38:11 +0000 2016
# 3     halfmylifede    ninadobrev        reply  fri apr 01 06:46:35 +0000 2016
# 4     halfmylifede  jessicaszohr     mentions  fri apr 01 06:46:35 +0000 2016
#
#              tweet id                                              tweet  \
# 0  715789342644510720                rt @yourcoollook: Я ДИКО ХОЧУ СПАТЬ
# 1  715789405554868224  налили в клей пва сметану и ходят жрут\nтп дно...
# 2  715790345070649345  ‘game of thrones’ star iain glen joins rachel ...
# 3  715792458983084032  @ninadobrev @jessicaszohr awhhh nina and vin s...
# 4  715792458983084032  @ninadobrev @jessicaszohr awhhh nina and vin s...
#
#         hashtags  retweet status
# ...

# %%
GoT_df.tail()
# Out:
#                  poster        recipient relationship  \
# 142571  gingerbirdevans  gingerbirdevans        tweet
# 142572  hussein__yassin       alixfusion        reply
# 142573        jecssssss        jecssssss        tweet
# 142574  toastedaquarius  toastedaquarius        tweet
# 142575        Madrid__3           arwa1z        reply
#
#                             tweet date            tweet id  \
# 142571  Fri Jul 01 05:46:48 +0000 2016  748754709784043523
# 142572  Fri Jul 01 05:49:38 +0000 2016  748755422845165568
# 142573  Fri Jul 01 05:52:25 +0000 2016  748756123277144068
# 142574  Fri Jul 01 05:55:12 +0000 2016  748756823730106368
# 142575  Fri Jul 01 05:55:12 +0000 2016  748756823721684994
#
#                                                     tweet  \
# 142571  wondered when someone would pick up on the  pa...
# 142572                                @alixfusion oum nem
# 142573  Just like Jon Snow, we know nothing 😂 #GameofT...
# ...

# %%
#Drop all where hashtag != gameofthrones

GoT_df['hashtags'] = GoT_df['hashtags'].str.lower()
GoT_df = GoT_df[GoT_df['hashtags'].str.contains('gameofthrones')]

# %%
GoT_df.head()
# Out:
#              poster        recipient relationship  \
# 9   harpersbazaarsg  harpersbazaarsg        tweet
# 10          shagil_        firstpost     mentions
# 15  gameofthrones1v  gameofthrones1v        tweet
# 18  jennieloveslife  jennieloveslife        tweet
# 19    davidgmcneill      syidmassiah     mentions
#
#                         tweet date            tweet id  \
# 9   fri apr 01 07:00:22 +0000 2016  715795927672496129
# 10  fri apr 01 07:02:47 +0000 2016  715796535875932160
# 15  fri apr 01 07:16:24 +0000 2016  715799962588692483
# 18  fri apr 01 07:26:20 +0000 2016  715802462389714944
# 19  fri apr 01 07:26:27 +0000 2016  715802491762384900
#
#                                                 tweet  \
# 9   this is just insane for a tv series: https://t...
# 10  rt @firstpost: 'heavy bubbles is secret of my ...
# 15  #gameofthrones game of thrones: season 3 (#dvd...
# 18  why is everybody lying about jon snow?\n\nhttp...
# ...

# %%
GoT_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102342 entries, 9 to 142574
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   poster          102342 non-null  object
#  1   recipient       102338 non-null  object
#  2   relationship    102342 non-null  object
#  3   tweet date      102342 non-null  object
#  4   tweet id        102342 non-null  int64
#  5   tweet           102342 non-null  object
#  6   hashtags        102342 non-null  object
#  7   retweet status  102342 non-null  bool
# dtypes: bool(1), int64(1), object(6)
# memory usage: 6.3+ MB

# %%
GoT_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102342 entries, 9 to 142574
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   poster          102342 non-null  object
#  1   recipient       102338 non-null  object
#  2   relationship    102342 non-null  object
#  3   tweet date      102342 non-null  object
#  4   tweet id        102342 non-null  int64
#  5   tweet           102342 non-null  object
#  6   hashtags        102342 non-null  object
#  7   retweet status  102342 non-null  bool
# dtypes: bool(1), int64(1), object(6)
# memory usage: 6.3+ MB

# %%
#Convert Year column to a datetime objest
#GoT_df['tweet date'] = pd.to_datetime(GoT_df['tweet date'])
#GoT_df['date'] = GoT_df['tweet date'].dt.date

# %%
GoT_df.head()
# Out:
#              poster        recipient relationship  \
# 9   harpersbazaarsg  harpersbazaarsg        tweet
# 10          shagil_        firstpost     mentions
# 15  gameofthrones1v  gameofthrones1v        tweet
# 18  jennieloveslife  jennieloveslife        tweet
# 19    davidgmcneill      syidmassiah     mentions
#
#                         tweet date            tweet id  \
# 9   fri apr 01 07:00:22 +0000 2016  715795927672496129
# 10  fri apr 01 07:02:47 +0000 2016  715796535875932160
# 15  fri apr 01 07:16:24 +0000 2016  715799962588692483
# 18  fri apr 01 07:26:20 +0000 2016  715802462389714944
# 19  fri apr 01 07:26:27 +0000 2016  715802491762384900
#
#                                                 tweet  \
# 9   this is just insane for a tv series: https://t...
# 10  rt @firstpost: 'heavy bubbles is secret of my ...
# 15  #gameofthrones game of thrones: season 3 (#dvd...
# 18  why is everybody lying about jon snow?\n\nhttp...
# ...

# %%
GoT_df.head()
# Out:
#              poster        recipient relationship  \
# 9   harpersbazaarsg  harpersbazaarsg        tweet
# 10          shagil_        firstpost     mentions
# 15  gameofthrones1v  gameofthrones1v        tweet
# 18  jennieloveslife  jennieloveslife        tweet
# 19    davidgmcneill      syidmassiah     mentions
#
#                         tweet date            tweet id  \
# 9   fri apr 01 07:00:22 +0000 2016  715795927672496129
# 10  fri apr 01 07:02:47 +0000 2016  715796535875932160
# 15  fri apr 01 07:16:24 +0000 2016  715799962588692483
# 18  fri apr 01 07:26:20 +0000 2016  715802462389714944
# 19  fri apr 01 07:26:27 +0000 2016  715802491762384900
#
#                                                 tweet  \
# 9   this is just insane for a tv series: https://t...
# 10  rt @firstpost: 'heavy bubbles is secret of my ...
# 15  #gameofthrones game of thrones: season 3 (#dvd...
# 18  why is everybody lying about jon snow?\n\nhttp...
# ...

# %%
#Save file for import to nosql
GoT_df.to_csv('C:\\data files\\All Clean.csv')
