# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Processing on the Monthly GoT data to remove false positives and do date processing

# %%
#Read in month of gameofthrones data
GoT_df = pd.read_csv('C:\\data files\\June2016 GOT.csv')

# %%
GoT_df.head()
# Out:
#           poster        recipient relationship  \
# 0          M04th           Cutevl        reply
# 1     aRnecutska  chris_voloshina     mentions
# 2     aRnecutska       aRnecutska     mentions
# 3   Macready1306     Macready1306        tweet
# 4  wahanapenulis    wahanapenulis        tweet
#
#                        tweet date            tweet id  \
# 0  Wed Jun 01 06:32:54 +0000 2016  737894675277852674
# 1  Wed Jun 01 06:34:15 +0000 2016  737895014991302656
# 2  Wed Jun 01 06:34:15 +0000 2016  737895014991302656
# 3  Wed Jun 01 06:35:56 +0000 2016  737895438624423937
# 4  Wed Jun 01 06:38:50 +0000 2016  737896168445870080
#
#                                                tweet           hashtags  \
# 0  @Cutevl انا اصداري اقدم شيء وعادي اخذ سيلفي ما...                 []
# 1  RT @chris_voloshina: @aRnecutska моё мнение: к...                 []
# 2  RT @chris_voloshina: @aRnecutska моё мнение: к...                 []
# 3  I've never watched #GameOfThrones so I'd love ...  ['GameOfThrones']
# 4  I'm Tyrion. Discover which #GameOfThrones char...  ['GameOfThrones']
#
#    retweet status
# 0           False
# 1            True
# 2            True
# 3           False
# 4           False

# %%
#Drop all where hashtag != gameofthrones

GoT_df['hashtags'] = GoT_df['hashtags'].str.lower()
GoT_df = GoT_df[GoT_df['hashtags'].str.contains('gameofthrones')]

# %%
GoT_df.head(12)
# Out:
#              poster        recipient relationship  \
# 3      Macready1306     Macready1306        tweet
# 4     wahanapenulis    wahanapenulis        tweet
# 6     scopece_marco  EmiliaClarkeNet     mentions
# 7     scopece_marco     emiliaclarke     mentions
# 8          Yayahemo       GoT_Tyrion     mentions
# 9      HodorRewards        jonsnowyy     mentions
# 10    ChuckForBlair         Daenerys     mentions
# 12  6516460c32f4431    FallonTonight     mentions
# 13        AK_____47    Thrones_Memes     mentions
# 14     smithstock24        Crackmacs     mentions
# 15     smithstock24           jaaxed     mentions
# 16       shahryar92       shahryar92        tweet
#
#                         tweet date            tweet id  \
# 3   Wed Jun 01 06:35:56 +0000 2016  737895438624423937
# 4   Wed Jun 01 06:38:50 +0000 2016  737896168445870080
# 6   Wed Jun 01 06:44:16 +0000 2016  737897535788961792
# 7   Wed Jun 01 06:44:16 +0000 2016  737897535788961792
# 8   Wed Jun 01 06:46:08 +0000 2016  737898005542674432
# 9   Wed Jun 01 06:49:03 +0000 2016  737898739558404096
# 10  Wed Jun 01 06:49:44 +0000 2016  737898911529066499
# 12  Wed Jun 01 07:04:47 +0000 2016  737902698985586688
# 13  Wed Jun 01 07:06:49 +0000 2016  737903210665512960
# 14  Wed Jun 01 07:15:15 +0000 2016  737905333004345344
# 15  Wed Jun 01 07:15:15 +0000 2016  737905333004345344
# 16  Wed Jun 01 07:15:43 +0000 2016  737905450419650560
#
#                                                 tweet  \
# 3   I've never watched #GameOfThrones so I'd love ...
# 4   I'm Tyrion. Discover which #GameOfThrones char...
# 6   RT @EmiliaClarkeNet: (Video) Emilia Clarke on ...
# 7   RT @EmiliaClarkeNet: (Video) Emilia Clarke on ...
# 8   RT @GoT_Tyrion: Who would do this?? #GameofThr...
# 9   RT @jonsnowyy: Well. I'm ready for GOT this we...
# 10  RT @Daenerys: Khal Drogo will never be replace...
# 12  RT @FallonTonight: Kit Harington was pretty te...
# 13  RT @Thrones_Memes: Girl Code #GameOfThrones ht...
# 14  RT @Crackmacs: Coolest. Gift. Ever. #hodor #ga...
# 15  RT @Crackmacs: Coolest. Gift. Ever. #hodor #ga...
# 16  I can't even... Forget #JonSnow, #MumtazQadri ...
#
#                                              hashtags  retweet status
# 3                                   ['gameofthrones']           False
# 4                                   ['gameofthrones']           False
# 6                                   ['gameofthrones']            True
# 7                                   ['gameofthrones']            True
# 8                                   ['gameofthrones']            True
# 9   ['gameofthrones', 'got', 'jonsnow', 'youknowno...            True
# 10                                  ['gameofthrones']            True
# 12                                  ['gameofthrones']            True
# 13                                  ['gameofthrones']            True
# 14                         ['hodor', 'gameofthrones']            True
# 15                         ['hodor', 'gameofthrones']            True
# 16        ['jonsnow', 'mumtazqadri', 'gameofthrones']           False

# %%
GoT_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47132 entries, 3 to 59268
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   poster          47132 non-null  object
#  1   recipient       47131 non-null  object
#  2   relationship    47132 non-null  object
#  3   tweet date      47132 non-null  object
#  4   tweet id        47132 non-null  int64
#  5   tweet           47132 non-null  object
#  6   hashtags        47132 non-null  object
#  7   retweet status  47132 non-null  bool
# dtypes: bool(1), int64(1), object(6)
# memory usage: 2.9+ MB

# %%
#Convert Year column to a datetime objest
GoT_df['tweet date'] = pd.to_datetime(GoT_df['tweet date'])

# %%
GoT_df.head(10)
# Out:
#              poster        recipient relationship                tweet date  \
# 3      Macready1306     Macready1306        tweet 2016-06-01 06:35:56+00:00
# 4     wahanapenulis    wahanapenulis        tweet 2016-06-01 06:38:50+00:00
# 6     scopece_marco  EmiliaClarkeNet     mentions 2016-06-01 06:44:16+00:00
# 7     scopece_marco     emiliaclarke     mentions 2016-06-01 06:44:16+00:00
# 8          Yayahemo       GoT_Tyrion     mentions 2016-06-01 06:46:08+00:00
# 9      HodorRewards        jonsnowyy     mentions 2016-06-01 06:49:03+00:00
# 10    ChuckForBlair         Daenerys     mentions 2016-06-01 06:49:44+00:00
# 12  6516460c32f4431    FallonTonight     mentions 2016-06-01 07:04:47+00:00
# 13        AK_____47    Thrones_Memes     mentions 2016-06-01 07:06:49+00:00
# 14     smithstock24        Crackmacs     mentions 2016-06-01 07:15:15+00:00
#
#               tweet id                                              tweet  \
# 3   737895438624423937  I've never watched #GameOfThrones so I'd love ...
# 4   737896168445870080  I'm Tyrion. Discover which #GameOfThrones char...
# 6   737897535788961792  RT @EmiliaClarkeNet: (Video) Emilia Clarke on ...
# 7   737897535788961792  RT @EmiliaClarkeNet: (Video) Emilia Clarke on ...
# 8   737898005542674432  RT @GoT_Tyrion: Who would do this?? #GameofThr...
# 9   737898739558404096  RT @jonsnowyy: Well. I'm ready for GOT this we...
# 10  737898911529066499  RT @Daenerys: Khal Drogo will never be replace...
# 12  737902698985586688  RT @FallonTonight: Kit Harington was pretty te...
# 13  737903210665512960  RT @Thrones_Memes: Girl Code #GameOfThrones ht...
# 14  737905333004345344  RT @Crackmacs: Coolest. Gift. Ever. #hodor #ga...
#
#                                              hashtags  retweet status
# 3                                   ['gameofthrones']           False
# 4                                   ['gameofthrones']           False
# 6                                   ['gameofthrones']            True
# 7                                   ['gameofthrones']            True
# 8                                   ['gameofthrones']            True
# 9   ['gameofthrones', 'got', 'jonsnow', 'youknowno...            True
# 10                                  ['gameofthrones']            True
# 12                                  ['gameofthrones']            True
# 13                                  ['gameofthrones']            True
# 14                         ['hodor', 'gameofthrones']            True

# %%
GoT_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47132 entries, 3 to 59268
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   poster          47132 non-null  object
#  1   recipient       47131 non-null  object
#  2   relationship    47132 non-null  object
#  3   tweet date      47132 non-null  datetime64[ns, UTC]
#  4   tweet id        47132 non-null  int64
#  5   tweet           47132 non-null  object
#  6   hashtags        47132 non-null  object
#  7   retweet status  47132 non-null  bool
# dtypes: bool(1), datetime64[ns, UTC](1), int64(1), object(5)
# memory usage: 2.9+ MB

# %%
#Add a month, day, week and year value to the dataframe
GoT_df['day'] = GoT_df['tweet date'].dt.day
GoT_df['week'] = GoT_df['tweet date'].dt.week
GoT_df['month'] = GoT_df['tweet date'].dt.month
GoT_df['year'] = GoT_df['tweet date'].dt.year
GoT_df['date'] = GoT_df['tweet date'].dt.date
# Out:
# C:\Users\tonyw\AppData\Local\Temp\ipykernel_3924\3577481597.py:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   GoT_df['week'] = GoT_df['tweet date'].dt.week

# %%
GoT_df.head()
# Out:
#           poster        recipient relationship                tweet date  \
# 3   Macready1306     Macready1306        tweet 2016-06-01 06:35:56+00:00
# 4  wahanapenulis    wahanapenulis        tweet 2016-06-01 06:38:50+00:00
# 6  scopece_marco  EmiliaClarkeNet     mentions 2016-06-01 06:44:16+00:00
# 7  scopece_marco     emiliaclarke     mentions 2016-06-01 06:44:16+00:00
# 8       Yayahemo       GoT_Tyrion     mentions 2016-06-01 06:46:08+00:00
#
#              tweet id                                              tweet  \
# 3  737895438624423937  I've never watched #GameOfThrones so I'd love ...
# 4  737896168445870080  I'm Tyrion. Discover which #GameOfThrones char...
# 6  737897535788961792  RT @EmiliaClarkeNet: (Video) Emilia Clarke on ...
# 7  737897535788961792  RT @EmiliaClarkeNet: (Video) Emilia Clarke on ...
# 8  737898005542674432  RT @GoT_Tyrion: Who would do this?? #GameofThr...
#
#             hashtags  retweet status  day  week  month  year        date
# 3  ['gameofthrones']           False    1    22      6  2016  2016-06-01
# 4  ['gameofthrones']           False    1    22      6  2016  2016-06-01
# 6  ['gameofthrones']            True    1    22      6  2016  2016-06-01
# 7  ['gameofthrones']            True    1    22      6  2016  2016-06-01
# 8  ['gameofthrones']            True    1    22      6  2016  2016-06-01

# %%
#Drop unwanted columns
#Dropping columns tweet id and tweet date as they are no longer needed
GoT_df.drop(['tweet date','tweet id'], axis=1,inplace=True)

# %%
GoT_df.head()
# Out:
#           poster        recipient relationship  \
# 3   Macready1306     Macready1306        tweet
# 4  wahanapenulis    wahanapenulis        tweet
# 6  scopece_marco  EmiliaClarkeNet     mentions
# 7  scopece_marco     emiliaclarke     mentions
# 8       Yayahemo       GoT_Tyrion     mentions
#
#                                                tweet           hashtags  \
# 3  I've never watched #GameOfThrones so I'd love ...  ['gameofthrones']
# 4  I'm Tyrion. Discover which #GameOfThrones char...  ['gameofthrones']
# 6  RT @EmiliaClarkeNet: (Video) Emilia Clarke on ...  ['gameofthrones']
# 7  RT @EmiliaClarkeNet: (Video) Emilia Clarke on ...  ['gameofthrones']
# 8  RT @GoT_Tyrion: Who would do this?? #GameofThr...  ['gameofthrones']
#
#    retweet status  day  week  month  year        date
# 3           False    1    22      6  2016  2016-06-01
# 4           False    1    22      6  2016  2016-06-01
# 6            True    1    22      6  2016  2016-06-01
# 7            True    1    22      6  2016  2016-06-01
# 8            True    1    22      6  2016  2016-06-01

# %%
#Save file for import to nosql
GoT_df.to_csv('C:\\data files\\June2016 GOT Clean.csv')
